# %%
from queue import Queue

# %%
class DAG:
    adj_list = {}
    reverse = {}
    edges = []
    nodes = []
    def __init__(self, adj_list):
        self.adj_list = adj_list

        self.traverse_bfs(lambda x: self.nodes.append(x))

        for v in adj_list.keys():
            for u in adj_list[v]:
                self.edges.append((v,u))
                self.reverse.setdefault(u,[]).append(v)

    def neighbors(self, node):
        return self.adj_list.setdefault(node, []) + self.reverse.setdefault([], node)

    def traverse_bfs(self, visitor):
        if len(self.adj_list.keys()) == 0:
            return
        q = Queue()
        visited = set()

        first = list(adj_list.keys())[0]

        q.put(first)

        while not q.empty():
            v = q.get()

            if v not in visited:
                visited.add(v)
            else:
                continue

            visitor(v)

            for u in self.adj_list[v]:
                q.put(u)

# %%
# Compute core numbers for vertices.
# Core number of a vertex is its degree.
def compute_cores(graph: DAG):
    size = len(graph.nodes)

    max_deg = 0
    deg = []
    order = []
    number = {}

    for idx, node in enumerate(graph.nodes):
        deg[idx] = len(graph.neighbors(node))
        number[node] = idx
        order[idx] = node
        max_deg = max(max_deg, deg[idx])

    bin = [None]*(max_deg + 1)
    
    # Count vertices in each bin.
    for i in range(0, size):
        bin[deg[i]] = bin[deg[i]] + 1

    # Sort by degree. Determine starting vertex in each bin.
    start = 0
    for i in range(0, max_deg + 1):
        tmp = bin[i]
        bin[i] = start
        start = start + tmp

    # Put sorted vertices into vert
    vert = [None]*size
    pos = [None]*size
    for i in range(0, size):
        pos[i] = bin[deg[i]]
        vert[pos[i]] = i
        bin[deg[i]] = bin[deg[i]] + 1

    # Recover starts.
    # - TODO: should go [max_deg, 0)
    for i in reversed(range(0, max_deg)):
        bin[i] = bin[i - 1]
    bin[0] = 0

    # Calculate core numbers
